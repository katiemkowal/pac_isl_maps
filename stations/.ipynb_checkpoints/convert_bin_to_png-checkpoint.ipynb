# %%
import os
from datetime import datetime,timedelta
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.colors import TwoSlopeNorm, LinearSegmentedColormap
import rioxarray as rio
from rasterio.warp import calculate_default_transform

# %%
cmorph_prd = '/cpc/fews/production/cmorph_cpcwork5/cmorph_RH6_BC_ADJ_EOD/output/bin/CMORPH_V1.0_ADJ_0.25deg-DLY_EOD_'
cmorph_clim = '/cpc/fews/production/cmorph_cpcwork5/cmorph_RH6_BC_ADJ_EOD/output/bin/clim_dly/clim_dly.'
figure_dir = '/cpc/int_desk/pac_isl/stations/images'
#from Ravi's ctl file for cmorph
xdim = 1440
ydim = 480
xmin = 0.125
xmax = 360
ymin = -59.875
ymax = 60
clipbox = [xmin, ymin, xmax, ymax]
min90anom = -25
max90anom = 25

# %%
def get_date_str(date):
    if date.month <10:
        cmonth_str = '0' + str(date.month)
    else:
        cmonth_str = str(date.month)
    if date.day <10:
        cday_str = '0' + str(date.day)
    else: cday_str = str(date.day)
    current_str = str(date.year) + cmonth_str + cday_str
    return current_str, cmonth_str+cday_str

# %%
def read_in_binary(location, xdim, ydim, xmin, xmax, ymin, ymax):
    if os.path.exists(location):
        with open(location, 'rb') as binary_file:
            binary_data = binary_file.read()
        data = np.frombuffer(binary_data, dtype = np.float32)
        data = data.reshape(ydim, xdim)
        lat = np.linspace(ymin, ymax, data.shape[0])
        lon = np.linspace(xmin, xmax, data.shape[1])
        da = xr.DataArray(data, dims = ['lat', 'lon'], coords = {'lat': lat, 'lon':lon})
        return da

# %%
from datetime import datetime, timedelta

# Get the current date
current_date = datetime.now().date()

# Get the date up to 95 days prior
last180_days_ago = current_date - timedelta(days=185)

# Generate a list of dates from seven_days_ago to current_date
last180 = [last180_days_ago + timedelta(days=i) for i in range(186)]  # 8 to include both endpoints

date_strs = []
for date in last180:
    date_strs.append((get_date_str(date)[0], get_date_str(date)[1]))

# %%
panom_da = []
panomclim_da = []
for d, date in enumerate(date_strs):
    da = read_in_binary(cmorph_prd + date[0], xdim, ydim, xmin, xmax, ymin, ymax)
    da_clim = read_in_binary(cmorph_clim + date[1], xdim, ydim, xmin, xmax, ymin, ymax)
    if da is not None:
        da = da.expand_dims({'time': [last180[d]]})
        da_clim = da_clim.expand_dims({'time':[last180[d]]})
        panom_da.append(da)
        panomclim_da.append(da_clim)
allptotal = xr.concat(panom_da, dim = 'time').to_dataset(name = 'ptotal') #.sum(dim = 'date')
allptotalclim = xr.concat(panomclim_da, dim = 'time').to_dataset(name = 'ptotalclim')
allptotal = allptotal.rename({'lon':'x', 'lat':'y'})
allptotalclim = allptotalclim.rename({'lon':'x', 'lat':'y'})

# %%
from matplotlib.colors import BoundaryNorm, ListedColormap
import matplotlib as mpl
# Define custom intervals for the colormap
value_intervals = [-25, -20, -15, -10, -5, -3, -2, -1, 1, 2, 3, 5, 10, 15, 20, 25]

# Define colors for the colormap (corresponding to your value intervals)
anom_colors = [
    (204/255, 51/255, 51/255), #dark red,
    (254/255,  4/255, 0/255), #bright red
    (255/255,  158/255, 0/255), #orange
    (255/255, 232/255, 123/255), #yellow
    (119/255,  79/255,  70/255), #dark brown
    (180/255, 140/255, 128/255), #med brown
    (237/255, 221/255, 212/255), #light brown
    (254/255, 254/255, 254/255), # off white
    (201/255, 254/255, 192/255), #light green
    (119/255, 244/255, 114/255), #bright green
    (30/255, 180/255,  30/255), #dark green
    (152/255, 210/255, 250/255), #lightmed blue
    (39/255, 129/255, 240/255), #darker blue
    (220/255, 220/255, 254/255), #light purple
    (127/255, 111/255, 234/255) #med purple
]

# Create a ListedColormap using your defined colors
anom_cmap = ListedColormap(anom_colors)

# Create a BoundaryNorm to map the data to the value intervals
norm = BoundaryNorm(boundaries=value_intervals, ncolors=len(anom_colors))

# %%
import pyproj

# Function to reproject the dataset to EPSG:3857
def convert_to_mercator(ds, var):
    ds_mercator = ds.rio.reproject("EPSG:3857", resolution=(1000, 1000))
    return ds_mercator

# Function to transform clipping bounds from EPSG:4326 to EPSG:3857
def transform_clip_bounds(xmin, ymin, xmax, ymax):
    # Setup the transformer from EPSG:4326 to EPSG:3857
    proj_4326 = pyproj.CRS('EPSG:4326')
    proj_3857 = pyproj.CRS('EPSG:3857')
    transformer = pyproj.Transformer.from_crs(proj_4326, proj_3857, always_xy=True)
    
    # Transform the clip bounds to Mercator
    xmin_mercator, ymin_mercator = transformer.transform(xmin, ymin)
    xmax_mercator, ymax_mercator = transformer.transform(xmax, ymax)
    
    return xmin_mercator, ymin_mercator, xmax_mercator, ymax_mercator

# Define the clip bounds in EPSG:4326 (longitude, latitude)
clip_bounds = [60, -50, 300, 45]  # xmin, ymin, xmax, ymax in EPSG:4326

# Transform the clip bounds to Mercator (EPSG:3857)
xmin_mercator, ymin_mercator, xmax_mercator, ymax_mercator = transform_clip_bounds(*clip_bounds)

# Process your dataset
last90_ds = allptotal.isel(time=slice(-90, None)).mean(dim='time')
last90_clim = allptotalclim.isel(time=slice(-90, None)).mean(dim='time')

# Compute the anomaly
last90_anom = (last90_ds.ptotal - last90_clim.ptotalclim).to_dataset(name='panom')

# Set CRS to EPSG:4326 for the dataset (assuming it's in geographic coordinates)
last90_anom_crs = last90_anom.rio.write_crs('EPSG:4326', inplace=True)

# Reproject the dataset to EPSG:3857 before clipping
last90_anom_mercator = convert_to_mercator(last90_anom_crs, 'panom')

# Check the dataset's Mercator bounds
print(f"Dataset Mercator Bounds: {last90_anom_mercator.rio.bounds()}")

# Clip the dataset using the transformed Mercator bounds
last90_anom_clipped = last90_anom_mercator.rio.clip_box(minx=xmin_mercator, miny=ymin_mercator,
                                                       maxx=xmax_mercator, maxy=ymax_mercator)

# Apply the clipping and visualize
np.clip(last90_anom_clipped.panom, min90anom, max90anom).plot(vmin=min90anom, vmax=max90anom)

# Normalize and plot the final result
last90_anomnorm = np.clip(last90_anom_clipped.panom, min90anom, max90anom)
# Out:
# Dataset Mercator Bounds: (-20037493.768347297, -8401350.34112984, 20037506.231652703, 8427649.65887016)
# ---------------------------------------------------------------------------
# WindowError                               Traceback (most recent call last)
# Input In [21], in <cell line: 44>()
#      41 print(f"Dataset Mercator Bounds: {last90_anom_mercator.rio.bounds()}")
#      43 # Clip the dataset using the transformed Mercator bounds
# ---> 44 last90_anom_clipped = last90_anom_mercator.rio.clip_box(minx=xmin_mercator, miny=ymin_mercator,
#      45                                                        maxx=xmax_mercator, maxy=ymax_mercator)
#      47 # Apply the clipping and visualize
#      48 np.clip(last90_anom_clipped.panom, min90anom, max90anom).plot(vmin=min90anom, vmax=max90anom)
#
# File ~/.conda/envs/map_env/lib/python3.9/site-packages/rioxarray/raster_dataset.py:292, in RasterDataset.clip_box(self, minx, miny, maxx, maxy, auto_expand, auto_expand_limit, crs)
#     289 try:
#     290     x_dim, y_dim = _get_spatial_dims(self._obj, var)
#     291     clipped_dataset[var] = (
# --> 292         self._obj[var]
#     293         .rio.set_spatial_dims(x_dim=x_dim, y_dim=y_dim, inplace=True)
#     294         .rio.clip_box(
#     295             minx,
#     296             miny,
#     297             maxx,
#     298             maxy,
#     299             auto_expand=auto_expand,
#     300             auto_expand_limit=auto_expand_limit,
#     301             crs=crs,
#     302         )
#     303     )
#     304 except MissingSpatialDimensionError:
#     305     if len(self._obj[var].dims) >= 2 and not get_option(
#     306         SKIP_MISSING_SPATIAL_DIMS
#     307     ):
#
# File ~/.conda/envs/map_env/lib/python3.9/site-packages/rioxarray/raster_array.py:830, in RasterArray.clip_box(self, minx, miny, maxx, maxy, auto_expand, auto_expand_limit, crs)
#     821     return self.clip_box(
#     822         minx=minx - abs(resolution_x) / 2.0,
#     823         miny=miny - abs(resolution_y) / 2.0,
#    (...)
#     827         auto_expand_limit=auto_expand_limit,
#     828     )
#     829 if window_error:
# --> 830     raise window_error
#     831 if cl_array.rio.width < 1 or cl_array.rio.height < 1:
#     832     raise NoDataInBounds(
#     833         f"No data found in bounds.{_get_data_var_message(self._obj)}"
#     834     )
#
# File ~/.conda/envs/map_env/lib/python3.9/site-packages/rioxarray/raster_array.py:807, in RasterArray.clip_box(self, minx, miny, maxx, maxy, auto_expand, auto_expand_limit, crs)
#     805 window_error = None
#     806 try:
# --> 807     window = rasterio.windows.from_bounds(
#     808         left=np.array(left).item(),
#     809         bottom=np.array(bottom).item(),
#     810         right=np.array(right).item(),
#     811         top=np.array(top).item(),
#     812         transform=self.transform(recalc=True),
#     813     )
#     814     cl_array: xarray.DataArray = self.isel_window(window)  # type: ignore
#     815 except rasterio.errors.WindowError as err:
#
# File ~/.conda/envs/map_env/lib/python3.9/site-packages/rasterio/windows.py:297, in from_bounds(left, bottom, right, top, transform, height, width, precision)
#     294     raise WindowError("A transform object is required to calculate the window")
#     296 if (right - left) / transform.a < 0:
# --> 297     raise WindowError("Bounds and transform are inconsistent")
#     299 if (bottom - top) / transform.e < 0:
#     300     raise WindowError("Bounds and transform are inconsistent")
#
# WindowError: Bounds and transform are inconsistent

# %%
def convert_to_mercator(ds, var):
    # ds = ds.where(~np.isnan(ds[var]), drop=True)
    ds_mercator = ds.rio.reproject("EPSG:3857")
    # ds_clip = ds_mercator.where(ds_mercator.notnull(), drop=True)
    return ds_mercator

last90_ds = allptotal.isel(time=slice(-90, None)).mean(dim = 'time')
last90_clim = allptotalclim.isel(time=slice(-90, None)).mean(dim = 'time')
last90_anom = (last90_ds.ptotal - last90_clim.ptotalclim).to_dataset(name = 'panom')
last90_anom_crs = last90_anom.rio.write_crs('EPSG:4326', inplace = True)
last90_anom_clipped = last90_anom.sel(x=slice(0.125,359.98), y = slice(-50,45))
print(last90_anom_clipped)
# last90_anom_clipped = last90_anom_crs.rio.clip_box(minx=60, miny=-50, 
#                                      maxx=300, maxy=45)
np.clip(last90_anom_clipped.panom, min90anom, max90anom).plot(vmin=min90anom,vmax=max90anom)
last90_anom_mc = convert_to_mercator(last90_anom_clipped, 'panom')
last90_anomnorm = np.clip(last90_anom_mc.panom, min90anom, max90anom)
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 380, x: 1439)
# Coordinates:
#   * y            (y) float64 -49.86 -49.61 -49.36 -49.11 ... 44.48 44.73 44.98
#   * x            (x) float64 0.125 0.3751 0.6252 0.8753 ... 359.2 359.5 359.7
#     spatial_ref  int64 0
# Data variables:
#     panom        (y, x) float32 1.746 1.67 1.62 1.636 ... 1.507 1.412 2.193

# %%
last90_anomnorm.x
# Out:
# <xarray.DataArray 'x' (x: 4936)>
# array([-20033442.665968, -20025323.979059, -20017205.292149, ...,
#         20016039.858367,  20024158.545276,  20032277.232186])
# Coordinates:
#   * x            (x) float64 -2.003e+07 -2.003e+07 ... 2.002e+07 2.003e+07
#     spatial_ref  int64 0
# Attributes:
#     axis:           X
#     long_name:      x coordinate of projection
#     standard_name:  projection_x_coordinate
#     units:          metre

# %%
# Apply the colormap and norm to the data
def apply_colormap(da, colormap, norm):
    """
    Apply a custom colormap to the data array based on specified boundaries.

    Parameters:
        da: xarray.DataArray
            The data array to which the colormap will be applied.
        colormap: matplotlib.colors.Colormap
            The custom colormap to apply.
        norm: matplotlib.colors.BoundaryNorm
            The normalizer that defines the color intervals.

    Returns:
        xarray.DataArray
            DataArray with RGBA values.
    """
    # Clip the data to the specified range (you could also use np.clip if needed)
    da_clipped = np.clip(da, value_intervals[0], value_intervals[-1])

    # Map the data values to the colormap using BoundaryNorm
    colormap_values = colormap(norm(da_clipped))

    # Scale to 0-255 for RGB and add an alpha channel
    da_rgb = (colormap_values[:, :, :3] * 255).astype(np.uint8)
    da_alpha = (~np.isnan(da_clipped)) * 255  # Transparency: 0 for NaN, 255 otherwise
    da_rgba = np.dstack((da_rgb, da_alpha.astype(np.uint8)))  # Combine RGB + Alpha

    # Convert to xarray for exporting with spatial coordinates
    da_rgba_xarray = xr.DataArray(
        da_rgba,
        dims=("y", "x", "band"),
        coords={"y": da.y, "x": da.x, "band": [1, 2, 3, 4]},
    )
    da_rgba_xarray = da_rgba_xarray.transpose("band", "y", "x").rio.write_crs(da.rio.crs)

    return da_rgba_xarray

# %%
last90_anomnorm.x
# Out:
# <xarray.DataArray 'x' (x: 4936)>
# array([-20033442.665968, -20025323.979059, -20017205.292149, ...,
#         20016039.858367,  20024158.545276,  20032277.232186])
# Coordinates:
#   * x            (x) float64 -2.003e+07 -2.003e+07 ... 2.002e+07 2.003e+07
#     spatial_ref  int64 0
# Attributes:
#     axis:           X
#     long_name:      x coordinate of projection
#     standard_name:  projection_x_coordinate
#     units:          metre

# %%
last90_rgb = apply_colormap(last90_anomnorm, anom_cmap, norm)

# %%
last90_rgb.rio.to_raster(os.path.join(figure_dir, 'cmorph90anom.png'), dtype="uint8")

# %%
plt.figure(figsize=(4, 4))  # Ensure the figure size is appropriate
plt.imshow(last90_anomnorm, 'coolwarm', vmin=min90anom, vmax=max90anom)

# %%
las90
